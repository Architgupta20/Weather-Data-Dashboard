# %%
from kafka import KafkaConsumer
import json
import pandas as pd
import os
import time

# %%
# Kafka Consumer Configuration
consumer = KafkaConsumer(
    "weather_data",  # Kafka topic name
    bootstrap_servers="localhost:9092",
    auto_offset_reset="latest",
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode("utf-8")),
)
# File path for saving data
file_path = "weather_data.csv"
print("✅ Consumer started listening for weather data...")
print("Saving to:", os.path.abspath(file_path))  # Print file path for debugging
# Out:
# ✅ Consumer started listening for weather data...
# Saving to: /Users/architgupta280/Desktop/Spark-DDP/Project/weather_data.csv

# %%
batch_size = 10  # Process data in batches of 10
buffer = []  # Temporary storage for 10 entries

# Infinite loop to continuously receive and store weather data
for message in consumer:
    weather_record = message.value
    print(f"Received: {weather_record}")

    buffer.append(weather_record)  # Add record to buffer

    # Process data only when 10 entries are collected
    if len(buffer) == batch_size:
        # Convert buffer to DataFrame
        new_data = pd.DataFrame(buffer)

        # Check if the file exists
        file_exists = os.path.isfile(file_path)

        # Save data to CSV (create if not exists, otherwise append)
        new_data.to_csv(file_path, mode="a", header=not file_exists, index=False)

        # Clear the buffer after saving
        buffer.clear()

        print("✅ Saved 10 records to file.")
        print("Waiting 30 seconds before the next round...")
        time.sleep(30)  # Wait 30 seconds before collecting the next 10 records
# Out:
# Received: {'timestamp': 1744199679, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 6.29, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199918, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744199719, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199674, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200021, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200239, 'city': 'Berlin', 'temperature': 13.8, 'humidity': 43, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200073, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199624, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199606, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744199679, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 6.29, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199624, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199624, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199921, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199770, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.31, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744199945, 'city': 'Sydney', 'temperature': 18.53, 'humidity': 78, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200528, 'city': 'Sydney', 'temperature': 18.38, 'humidity': 80, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744199924, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200195, 'city': 'London', 'temperature': 12.65, 'humidity': 58, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200133, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200528, 'city': 'Sydney', 'temperature': 18.38, 'humidity': 80, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200513, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200531, 'city': 'London', 'temperature': 11.78, 'humidity': 63, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200800, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200528, 'city': 'Sydney', 'temperature': 18.38, 'humidity': 80, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200513, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200531, 'city': 'London', 'temperature': 11.78, 'humidity': 63, 'wind_speed': 4.45, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744200800, 'city': 'Tokyo', 'temperature': 15.08, 'humidity': 49, 'wind_speed': 6.38, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200537, 'city': 'Delhi', 'temperature': 40.64, 'humidity': 10, 'wind_speed': 1.25, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200180, 'city': 'Paris', 'temperature': 16.43, 'humidity': 35, 'wind_speed': 4.13, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200035, 'city': 'Berlin', 'temperature': 14.01, 'humidity': 45, 'wind_speed': 3.42, 'weather_condition': 'broken clouds'}
# Received: {'timestamp': 1744200528, 'city': 'Sydney', 'temperature': 18.38, 'humidity': 80, 'wind_speed': 4.67, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200612, 'city': 'Toronto', 'temperature': -2.44, 'humidity': 49, 'wind_speed': 3.28, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200144, 'city': 'Dubai', 'temperature': 34.16, 'humidity': 55, 'wind_speed': 5.81, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744200513, 'city': 'Singapore', 'temperature': 29.29, 'humidity': 83, 'wind_speed': 3.57, 'weather_condition': 'light rain'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744200310, 'city': 'New York', 'temperature': -0.55, 'humidity': 41, 'wind_speed': 5.93, 'weather_condition': 'clear sky'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 buffer = []  # Temporary storage for 10 entries
#       4 # Infinite loop to continuously receive and store weather data
# ----> 5 for message in consumer:
#       6     weather_record = message.value
#       7     print(f"Received: {weather_record}")
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/consumer/group.py:1168, in KafkaConsumer.__next__(self)
#    1166     self._iterator = self._message_generator_v2()
#    1167 try:
# -> 1168     return next(self._iterator)
#    1169 except StopIteration:
#    1170     self._iterator = None
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/consumer/group.py:1140, in KafkaConsumer._message_generator_v2(self)
#    1138 def _message_generator_v2(self):
#    1139     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1140     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1141     for tp, records in six.iteritems(record_map):
#    1142         # Generators are stateful, and it is possible that the tp / records
#    1143         # here may become stale during iteration -- i.e., we seek to a
#    1144         # different offset, pause consumption, or lose assignment.
#    1145         for record in records:
#    1146             # is_fetchable(tp) should handle assignment changes and offset
#    1147             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1148             # outer function destroying the existing iterator/generator
#    1149             # via self._iterator = None
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/consumer/group.py:679, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     677 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     678 while not self._closed:
# --> 679     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     680     if records:
#     681         return records
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/consumer/group.py:722, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     719 if records:
#     720     return records
# --> 722 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     723 # after the long poll, we should check whether the group needs to rebalance
#     724 # prior to returning data so that the group can stabilize faster
#     725 if self._coordinator.need_rejoin():
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/client_async.py:683, in KafkaClient.poll(self, timeout_ms, future)
#     676         timeout = min(
#     677             user_timeout_ms,
#     678             metadata_timeout_ms,
#     679             idle_connection_timeout_ms,
#     680             request_timeout_ms)
#     681         timeout = max(0, timeout)  # avoid negative timeouts
# --> 683     self._poll(timeout / 1000)
#     685 # called without the lock to avoid deadlock potential
#     686 # if handlers need to acquire locks
#     687 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/site-packages/kafka/client_async.py:726, in KafkaClient._poll(self, timeout)
#     723 self._register_send_sockets()
#     725 start_select = time.time()
# --> 726 ready = self._selector.select(timeout)
#     727 end_select = time.time()
#     728 if self._sensors:
#
# File /opt/anaconda3/envs/SparkLabs/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
