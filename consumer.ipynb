# %%
from kafka import KafkaConsumer
import json
import pandas as pd
import os
import time

# %%
# Kafka Consumer Configuration
consumer = KafkaConsumer(
    "weather_data",  # Kafka topic name
    bootstrap_servers="localhost:9092",
    auto_offset_reset="latest",
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode("utf-8")),
)
# File path for saving data
file_path = "weather_data.csv"
print("✅ Consumer started listening for weather data...")
print("Saving to:", os.path.abspath(file_path))  # Print file path for debugging
# Out:
# ✅ Consumer started listening for weather data...
# Saving to: /Users/architgupta280/Desktop/Spark-DDP/Project/weather_data.csv

# %%
batch_size = 10  # Process data in batches of 10
buffer = []  # Temporary storage for 10 entries

# Infinite loop to continuously receive and store weather data
for message in consumer:
    weather_record = message.value
    print(f"Received: {weather_record}")

    buffer.append(weather_record)  # Add record to buffer

    # Process data only when 10 entries are collected
    if len(buffer) == batch_size:
        # Convert buffer to DataFrame
        new_data = pd.DataFrame(buffer)

        # Check if the file exists
        file_exists = os.path.isfile(file_path)

        # Save data to CSV (create if not exists, otherwise append)
        new_data.to_csv(file_path, mode="a", header=not file_exists, index=False)

        # Clear the buffer after saving
        buffer.clear()

        print("✅ Saved 10 records to file.")
        print("Waiting 30 seconds before the next round...")
        time.sleep(30)  # Wait 30 seconds before collecting the next 10 records
# Out:
# Received: {'timestamp': 1744311386, 'city': 'New York', 'temperature': 8.65, 'humidity': 47, 'wind_speed': 7.02, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744310944, 'city': 'London', 'temperature': 12.01, 'humidity': 63, 'wind_speed': 0.97, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311263, 'city': 'Tokyo', 'temperature': 15.03, 'humidity': 69, 'wind_speed': 3.21, 'weather_condition': 'moderate rain'}
# Received: {'timestamp': 1744311594, 'city': 'Delhi', 'temperature': 33.13, 'humidity': 20, 'wind_speed': 0.79, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311674, 'city': 'Paris', 'temperature': 14.21, 'humidity': 52, 'wind_speed': 3.33, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311676, 'city': 'Berlin', 'temperature': 11.55, 'humidity': 60, 'wind_speed': 4.86, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311386, 'city': 'Sydney', 'temperature': 15.45, 'humidity': 87, 'wind_speed': 2.33, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744311680, 'city': 'Toronto', 'temperature': 2.9, 'humidity': 61, 'wind_speed': 6.34, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311076, 'city': 'Dubai', 'temperature': 27.21, 'humidity': 63, 'wind_speed': 1.24, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311632, 'city': 'Singapore', 'temperature': 27.06, 'humidity': 82, 'wind_speed': 2.88, 'weather_condition': 'scattered clouds'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744311386, 'city': 'New York', 'temperature': 8.65, 'humidity': 47, 'wind_speed': 7.02, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744310944, 'city': 'London', 'temperature': 12.01, 'humidity': 63, 'wind_speed': 0.97, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311263, 'city': 'Tokyo', 'temperature': 15.03, 'humidity': 69, 'wind_speed': 3.21, 'weather_condition': 'moderate rain'}
# Received: {'timestamp': 1744311594, 'city': 'Delhi', 'temperature': 33.13, 'humidity': 20, 'wind_speed': 0.79, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311674, 'city': 'Paris', 'temperature': 14.21, 'humidity': 52, 'wind_speed': 3.33, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311676, 'city': 'Berlin', 'temperature': 11.55, 'humidity': 60, 'wind_speed': 4.86, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311386, 'city': 'Sydney', 'temperature': 15.45, 'humidity': 87, 'wind_speed': 2.33, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744311680, 'city': 'Toronto', 'temperature': 2.9, 'humidity': 61, 'wind_speed': 6.34, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311076, 'city': 'Dubai', 'temperature': 27.21, 'humidity': 63, 'wind_speed': 1.24, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311632, 'city': 'Singapore', 'temperature': 27.06, 'humidity': 82, 'wind_speed': 2.88, 'weather_condition': 'scattered clouds'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744311386, 'city': 'New York', 'temperature': 8.65, 'humidity': 47, 'wind_speed': 7.02, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744310944, 'city': 'London', 'temperature': 12.01, 'humidity': 63, 'wind_speed': 0.97, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311263, 'city': 'Tokyo', 'temperature': 15.03, 'humidity': 69, 'wind_speed': 3.21, 'weather_condition': 'moderate rain'}
# Received: {'timestamp': 1744311594, 'city': 'Delhi', 'temperature': 33.13, 'humidity': 20, 'wind_speed': 0.79, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311674, 'city': 'Paris', 'temperature': 14.21, 'humidity': 52, 'wind_speed': 3.33, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311676, 'city': 'Berlin', 'temperature': 11.55, 'humidity': 60, 'wind_speed': 4.86, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311386, 'city': 'Sydney', 'temperature': 15.45, 'humidity': 87, 'wind_speed': 2.33, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744311680, 'city': 'Toronto', 'temperature': 2.9, 'humidity': 61, 'wind_speed': 6.34, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311076, 'city': 'Dubai', 'temperature': 27.21, 'humidity': 63, 'wind_speed': 1.24, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311632, 'city': 'Singapore', 'temperature': 27.06, 'humidity': 82, 'wind_speed': 2.88, 'weather_condition': 'scattered clouds'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744311386, 'city': 'New York', 'temperature': 8.65, 'humidity': 47, 'wind_speed': 7.02, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311569, 'city': 'London', 'temperature': 12.01, 'humidity': 63, 'wind_speed': 0.97, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311263, 'city': 'Tokyo', 'temperature': 15.03, 'humidity': 69, 'wind_speed': 3.21, 'weather_condition': 'moderate rain'}
# Received: {'timestamp': 1744311594, 'city': 'Delhi', 'temperature': 33.13, 'humidity': 20, 'wind_speed': 0.79, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311674, 'city': 'Paris', 'temperature': 14.21, 'humidity': 52, 'wind_speed': 3.33, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311676, 'city': 'Berlin', 'temperature': 11.55, 'humidity': 60, 'wind_speed': 4.86, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311386, 'city': 'Sydney', 'temperature': 15.45, 'humidity': 87, 'wind_speed': 2.33, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744311680, 'city': 'Toronto', 'temperature': 2.9, 'humidity': 61, 'wind_speed': 6.34, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311076, 'city': 'Dubai', 'temperature': 27.21, 'humidity': 63, 'wind_speed': 1.24, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311632, 'city': 'Singapore', 'temperature': 27.06, 'humidity': 82, 'wind_speed': 2.88, 'weather_condition': 'scattered clouds'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
# Received: {'timestamp': 1744311392, 'city': 'New York', 'temperature': 8.65, 'humidity': 47, 'wind_speed': 7.02, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311232, 'city': 'London', 'temperature': 12.01, 'humidity': 63, 'wind_speed': 0.97, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311263, 'city': 'Tokyo', 'temperature': 15.03, 'humidity': 69, 'wind_speed': 3.21, 'weather_condition': 'moderate rain'}
# Received: {'timestamp': 1744311594, 'city': 'Delhi', 'temperature': 33.13, 'humidity': 20, 'wind_speed': 0.79, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311186, 'city': 'Paris', 'temperature': 14.21, 'humidity': 52, 'wind_speed': 3.33, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311368, 'city': 'Berlin', 'temperature': 11.55, 'humidity': 60, 'wind_speed': 4.86, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311386, 'city': 'Sydney', 'temperature': 15.45, 'humidity': 87, 'wind_speed': 2.33, 'weather_condition': 'few clouds'}
# Received: {'timestamp': 1744311234, 'city': 'Toronto', 'temperature': 2.9, 'humidity': 61, 'wind_speed': 6.34, 'weather_condition': 'overcast clouds'}
# Received: {'timestamp': 1744311076, 'city': 'Dubai', 'temperature': 27.21, 'humidity': 63, 'wind_speed': 1.24, 'weather_condition': 'clear sky'}
# Received: {'timestamp': 1744311545, 'city': 'Singapore', 'temperature': 27.06, 'humidity': 82, 'wind_speed': 2.88, 'weather_condition': 'scattered clouds'}
# ✅ Saved 10 records to file.
# Waiting 30 seconds before the next round...
